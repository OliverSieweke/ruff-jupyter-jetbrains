# %%
print(a) # (F821): Undefined name `a`
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 print(a)
#
# NameError: name 'a' is not defined

# %%
from os import * # (F403): `from os import *` used; unable to detect undefined names

# %%
def my_function(): # (F811): Redefinition of unused `my_function` from cell 3, line 1: `my_function` redefined here
    pass

def my_function():  # (F811): Redefinition of unused `my_function` from cell 3, line 4: `my_function` redefined here
    return 42

# %%
def test():
    print(x) #  (F405): `x` may be undefined, or defined from star imports
    x = 10 # (F841): Local variable `x` is assigned to but never use
